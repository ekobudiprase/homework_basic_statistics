# %% [markdown]
# # Homework of Basic Statistics for Data Science in Python
# **Telkomsel Data Science Academy**
# <br> 9 October 2019
# <br> done by : **Eko Budi P, 89170**

# %%
import pandas as pd
import statistics as st

# %%
#1. Load googleplaystore_user_reviews.csv file from dataset folder, 
# and assign it as df_review.  
# Fill this gap (___) and uncomment the following line! 
df_review = pd.read_csv("dataset/googleplaystore_user_reviews.csv",encoding='latin1')
df_review.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
#2. How many rows and columns for df_review? 
# Write your code here 
df_review.shape
# Out:
# (64295, 5)

# %%
#3. How many NaN value in dataset for each columns? 
# Write your code here (Hint: isnull and sum)
df_review.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
#4. Perform drop all NaN values and assign as new data frame named df_rev_clean
# Write your code here (Hint: dropna)
df_rev_clean = df_review.dropna(inplace=False)

# %%
#5. Upon dropping, how many rows and columns remaining?
# Write your code here
df_rev_clean.shape
# Out:
# (37427, 5)

# %%
#6. Perform simple random sampling with only 3 sample 
# towards df_rev_clean with random_state=10 without replacement. 
# Write your code here (Hint: sample)
df_rev_clean.sample(n=3,random_state=10, replace=False)
# Out:
#                                    App      Translated_Review Sentiment  \
# 12028   Badoo - Free Chat & Dating App           Rubbish app.   Neutral
# 35092  Docs To Goâ¢ Free Office Suite        Very lite app..  Positive
# 48816    Free & Premium VPN - FinchVPN  Nice, works Android 8  Positive
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 12028                 0.0                     0.0
# 35092                 0.2                     0.3
# 48816                 0.6                     1.0

# %%
# 7. Perform stratified random sampling for each sentiment (Neutral, Positive, and Negative) 
# with the following conditions:
# 10 sample size per strata/group
# random state = 10
# without replacement
# assign as df_sample dataframe 

# Fill up the gap (___) and uncomment the following code
fn = lambda x: x.sample(n=100, random_state=10, replace=False)
df_sample = df_rev_clean.groupby('Sentiment', as_index=False).apply(fn)
df_sample
# Out:
#                                                        App  \
# 0 24841                     Cat Sim Online: Play with Cats
#   708           30 Day Fitness Challenge - Workout at Home
#   1610                        8fit Workouts & Meal Planner
#   7306                           Anger of stick 5 : zombie
#   5843                                 All Social Networks
#   40863                     Etsy: Handmade & Vintage Goods
#   21756                           Calorie Counter - Macros
#   62024                                  Hill Climb Racing
#   13237                                Be A Legend: Soccer
#   35864                           DoorDash - Food Delivery
#   44724                                   Fashion in Vogue
#   13007                                   Basketball Stars
#   23328                             Candy Crush Jelly Saga
#   12934                                   Basketball Stars
#   23409                                   Candy Crush Saga
#   62813                   Home Street â Home Design Game
#   13377                     Beautiful Design Birthday Cake
#   38722                      Easy - taxi, car, ridesharing
#   42296                                                FOX
#   30982                     Crunchyroll - Everything Anime
#   12064                     Badoo - Free Chat & Dating App
#   18381                              Bubble Shooter Genies
#   9842                                                Azar
#   23789                              Candy Crush Soda Saga
#   39050                     Eat Fit - Diet and Health Free
#   3644                                     Account Manager
#   45782                     Final Fantasy XV: A New Empire
#   7375                                 Angry Birds Classic
#   32525                  DSLR Camera Hd Ultra Professional
#   62279                      Hinge: Dating & Relationships
# ...                                                    ...
# 2 8182   Any.do: To-do list, Calendar, Reminders & Planner
#   47910                                       Food Network
#   1573                              850 Sports News Digest
#   24917                             Caviar - Food Delivery
#   1065                              591æ¿å±äº¤æ-é¦æ¸¯
#   6105                                    Alto's Adventure
#   37577                     Duolingo: Learn Languages Free
#   18900                     Buzz Launcher-Smart&Free Theme
#   60800                                         Helix Jump
#   60827                                         Helix Jump
#   18525                                    Build a Bridge!
#   32331              DMV Permit Practice Test 2018 Edition
#   46374                                            Fishdom
#   57597                     Groovebook Photo Books & Gifts
#   38943                                       Easy Recipes
#   4757                       Agoda â Hotel Booking Deals
#   37203                    DroidAdmin for Android - Advice
#   22155                     Calorie Counter - MyFitnessPal
#   37260                                            Dropbox
#   10508                        BBW Dating & Plus Size Chat
#   47699                                          Fly Delta
#   28611                                     Comedy Central
#   21773                           Calorie Counter - Macros
#   49974                                 FreshBooks Classic
#   27971           Color by Number - Draw Sandbox Pixel Art
#   54202   Goibibo - Flight Hotel Bus Car IRCTC Booking App
#   17342                                    Boxed Wholesale
#   4178                                Adobe Acrobat Reader
#   58759                                HESI A2 Pocket Prep
#   38954                                       Easy Recipes
#
#                                          Translated_Review Sentiment  \
# 0 24841  So multiplayer game name, like server about, a...  Negative
#   708                     I hate forces exercise everyday.  Negative
#   1610   After two days using app, simply stopped worki...  Negative
#   7306                  Its really cool game keeps engaged  Negative
#   5843                                             Dumb fb  Negative
#   40863  Works wants i'm sick message Uh oh problem Try...  Negative
#   21756  'search online' simply work, freezes time I tr...  Negative
#   62024  Why link contact idiots designed game? There s...  Negative
#   13237  Sick This game makes sick work everything acco...  Negative
#   35864  At beginning fine, longer I it, worse gotten. ...  Negative
#   44724  Not perfect I like interface smooth be. I want...  Negative
#   13007   The game play run money quit rejoin keep playing  Negative
#   23328  I've playing game long long time. But every ti...  Negative
#   12934  Blocked opponents shot clutch game. The game g...  Negative
#   23409  I would enjoy game SO MUCH MORE option turn fl...  Negative
#   62813   I stop game cause I press button . It didnt work  Negative
#   13377                                     Not worth to..  Negative
#   38722                 The promotions are always outdated  Negative
#   42296  Updated, and stopped working. Says I need to c...  Negative
#   30982  Absolutely awful. In standard episode 4 advert...  Negative
#   12064  When selecting 'Show Online' profiles idicatio...  Negative
#   18381   The game level 56 difficult .please make easier.  Negative
#   9842                          It's waste ....third grade  Negative
#   23789  Love game. Hate open current level. Web recogn...  Negative
#   39050  English language? The recipes unknown English ...  Negative
#   3644   Like many others comments Aqua M4 got faults c...  Negative
#   45782  No point playing game unless prepared spend th...  Negative
#   7375   Love game every 1 min game play watch 2 min ad...  Negative
#   32525  This much better normal camera I hate .. body ...  Negative
#   62279  I like it, potential however issues; cant uplo...  Negative
# ...                                                    ...       ...
# 2 8182                                            Love it,  Positive
#   47910  This longer (as August 1st, 2018) lets watch s...  Positive
#   1573   Amazing This great soon I get I check sports n...  Positive
#   24917      It good helping peoples make easy live better  Positive
#   1065   æµæ¥¼ç§æ¥¼ A lot of time, a lot of time mana...  Positive
#   6105   I never write reviews first foremost. I absolu...  Positive
#   37577  Awesome app, entire family installed us starte...  Positive
#   18900  Great customize everything there. One thing th...  Positive
#   60800  I Would've loved give game better review, Ads ...  Positive
#   60827  The game play good. My issue even though paid ...  Positive
#   18525                                   I love game much  Positive
#   32331  Very useful, getting unlock different levels i...  Positive
#   46374  Love game. Very addictive I enjoy able decorat...  Positive
#   57597  The order takes month get you. Plus quality pa...  Positive
#   38943             Clear comprehensive culinary delights.  Positive
#   4757   I used Alots booking far best even prices ofte...  Positive
#   37203  Stop naming using icons connected popular peop...  Positive
#   22155                        Will let log many attempts.  Positive
#   37260                    Excellent working great elegant  Positive
#   10508  Deleted within 10 minutes. Imagine member accu...  Positive
#   47699  Works well works. (Use much better). The locks...  Positive
#   28611  Great update Android TV app. Excellent new int...  Positive
#   21773  Liked before, upgrades helped alot. I used nev...  Positive
#   49974  Recommended linus tech tips. Very good app. I ...  Positive
#   27971  I love used old phone new 10 times much better...  Positive
#   54202                                     fast easy use.  Positive
#   17342  I'm saving prime...ative fees year sticking bo...  Positive
#   4178   And exactly wth I account / sign view print pd...  Positive
#   58759                   This best way prepare hesi exam!  Positive
#   38954                                   Yummy tummy. LOL  Positive
#
#          Sentiment_Polarity  Sentiment_Subjectivity
# 0 24841           -0.350000                0.400000
#   708             -0.500000                0.750000
#   1610            -0.062500                0.339286
#   7306            -0.025000                0.525000
#   5843            -0.375000                0.500000
#   40863           -0.257143                0.478571
#   21756           -0.033333                0.426190
#   62024           -0.183333                0.254167
#   13237           -0.282143                0.678571
#   35864           -0.129167                0.600000
#   44724           -0.050000                0.750000
#   13007           -0.400000                0.400000
#   23328           -0.012500                0.534615
#   12934           -0.144444                0.583333
#   23409           -0.012955                0.545455
#   62813           -0.400000                0.400000
#   13377           -0.150000                0.100000
#   38722           -0.400000                0.633333
#   42296           -0.520000                0.780000
#   30982           -0.425000                0.441667
#   12064           -0.100000                0.275000
#   18381           -0.450000                0.700000
#   9842            -0.200000                0.000000
#   23789           -0.241667                0.633333
#   39050           -0.176250                0.300000
#   3644            -0.077474                0.300000
#   45782           -0.093197                0.590476
#   7375            -0.128571                0.428571
#   32525           -0.087500                0.512500
#   62279           -0.250000                0.750000
# ...                     ...                     ...
# 2 8182             0.500000                0.600000
#   47910            0.175000                0.275000
#   1573             0.733333                0.800000
#   24917            0.442424                0.608333
#   1065             0.433333                0.833333
#   6105             0.056250                0.494345
#   37577            0.242857                0.575000
#   18900            0.450000                0.475000
#   60800            0.181250                0.475000
#   60827            0.240000                0.629048
#   18525            0.100000                0.400000
#   32331            0.147500                0.300000
#   46374            0.041667                0.665625
#   57597            0.381250                0.489583
#   38943            0.050000                0.191667
#   4757             0.550000                0.650000
#   37203            0.600000                0.900000
#   22155            0.500000                0.500000
#   37260            0.766667                0.916667
#   10508            0.200000                0.691667
#   47699            0.270833                0.470833
#   28611            0.645455                0.734848
#   21773            0.412500                0.693750
#   49974            0.910000                0.780000
#   27971            0.167273                0.430909
#   54202            0.316667                0.716667
#   17342            0.500000                0.500000
#   4178             0.022222                0.550000
#   58759            1.000000                0.300000
#   38954            0.800000                0.700000
#
# [300 rows x 5 columns]

# %%
#8. What is the mode value of Sentiment from df_rev_clean data frame? 

# Write your code here (Hint: sample)
st.mode(df_rev_clean.Sentiment)
# Out:
# 'Positive'

# %%
#9. What is the mode value of Sentiment on df_sample data frame? Why error popped up?
# st.mode(df_sample.Sentiment)
st.mode(df_sample.Sentiment)
# error popped up because no unique mode, its exactly same 100 data on 3 group
# Out:
# ---------------------------------------------------------------------------
# StatisticsError                           Traceback (most recent call last)
# <ipython-input-29-3648b8c8808d> in <module>
#       1 #9. What is the mode value of Sentiment on df_sample data frame? Why error popped up?
#       2 # st.mode(df_sample.Sentiment)
# ----> 3 st.mode(df_sample.Sentiment)
#
# ~\Anaconda3\lib\statistics.py in mode(data)
#     504     elif table:
#     505         raise StatisticsError(
# --> 506                 'no unique mode; found %d equally common values' % len(table)
#     507                 )
#     508     else:
#
# StatisticsError: no unique mode; found 3 equally common values

# %%
#10. How many positive, negative, and neutral in Sentiment column of df_rev_clean data frame?

# Fill in the gap (___) and uncomment the following code
df_rev_clean["Sentiment"].value_counts()
# Out:
# Positive    23998
# Negative     8271
# Neutral      5158
# Name: Sentiment, dtype: int64

# %%
#11. What is the mean value of sentiment_polarity and Sentiment Subjectivity of 'Angry Birds Classic'? 

# Write your code here
df_rev_clean.loc[dw_rev_clean['App']=='Angry Birds Classic'].groupby('App', as_index=False).mean()
# Out:
#                    App  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Angry Birds Classic           -0.007537                0.534886

# %%
#12. How many Angry Birds Classic rows were included in df_rev_clean data frame?

# Write your code here
df_rev_clean.loc[dw_rev_clean['App']=='Angry Birds Classic'].shape
# Out:
# (273, 5)

# %%
#13. What is the median value of sentiment polarity and Sentiment Subjectivity of 'Candy Crush Saga'?

# Write your code here (Hint: median)
df_rev_clean.loc[dw_rev_clean['App']=='Candy Crush Saga'].groupby('App', as_index=False).median()
# Out:
#                 App  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Candy Crush Saga           -0.011023                0.481629

# %%
#14. What is the mode value of App in the df_rev_clean? - This apps has highest number of rows in the dataset. 

# Write your code here (Hint: st.mode)
st.mode(df_rev_clean.App)
# Out:
# 'Bowmasters'

# %%
#15. What is the correlation value between Sentiment Polarity and Sentiment Subjectivity 
# using spearman, pearson, and kendall

# Fill in the gap and change the method using spearman, pearson, and kendall!
df_rev_clean.filter(like="Sentiment_").corr(method='spearman')
# Out:
#                         Sentiment_Polarity  Sentiment_Subjectivity
# Sentiment_Polarity                1.000000                0.351522
# Sentiment_Subjectivity            0.351522                1.000000

# %%
df_rev_clean.filter(like="Sentiment_").corr(method='pearson')
# Out:
#                         Sentiment_Polarity  Sentiment_Subjectivity
# Sentiment_Polarity                1.000000                0.261587
# Sentiment_Subjectivity            0.261587                1.000000

# %%
df_rev_clean.filter(like="Sentiment_").corr(method='kendall')
# Out:
#                         Sentiment_Polarity  Sentiment_Subjectivity
# Sentiment_Polarity                1.000000                0.259973
# Sentiment_Subjectivity            0.259973                1.000000
